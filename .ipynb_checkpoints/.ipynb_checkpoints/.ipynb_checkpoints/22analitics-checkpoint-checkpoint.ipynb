# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import pyplot

# %%
all_fields = pd.read_csv('C:/Users/yayar/OneDrive/Рабочий стол/b2/sonicDataAnalizeYaro/csv/22Data.csv',delimiter=',')

# %%
display(all_fields)
# Out:
#     id                                name age  sex       link  \
# 0    1           Михаил Вячеславович Матов  22    0  undefined
# 1    2           Анна Менделеевна Рапопорт  42    0  undefined
# 2    3          Ирина Дмитриевна Зеленская  46    0  undefined
# 3    4          Софья Васильевна Дрыжакова  69    0  undefined
# 4    5        Николай Николаевич Иноземцев  20    0  undefined
# 5    6           Наум Самойлович Файнштейн  34    0  undefined
# 6    7     Александр Николаевич Афиногенов  37    0  undefined
# 7    8            Юрий Сергеевич Никифоров  22    0  undefined
# 8    9           Георгий Алексеевич Князев  54    0  undefined
# 9   10        Михаил Александрович Сидоров  23    0  undefined
# 10  11          Михаил Георгиевич Павлухин   ?    0  undefined
# 11  12       Зинаида Александровна Шиленок  24    0  undefined
# 12  13         Владимир Бузинаевич Борсоев  35    0  undefined
# 13  14         Виталий Валентинович Бианки  47    0  undefined
# 14  15         Наталия Николаевна Паульсен  17    0  undefined
# 15  16      Михаил Валентинович Кульчицкий  21    0  undefined
# 16  17            Людмила Васильевна Хомич  19    0  undefined
# 17  18               Зара Григорьевна Минц  14    0  undefined
# 18  19         Владимир Михайлович Голицын  39    0  undefined
# 19  20           Михаил Михайлович Пришвин  68    0  undefined
# 20  21           Мария Сергеевна Коноплева  70    0  undefined
# 21  22  Александр Александрович Бардовский  48    0  undefined
# 22  23                     Мартин  Штеглих  26    0  undefined
# 23  24    Николай Александрович Кондратьев  35    0  undefined
# 24  25        Дмитрий Венедиктович Жигунов  35    0  undefined
#
#                                                  text
# 0   Приехали на границу. Заняли сопку. Строим обор...
# 1   Поговаривают о скором переводе детей в город. ...
# 2   Месяц войны. Отпразднован этот юбилей немцами ...
# 3   Вчера ночная тревога была ощутимее по усталост...
# 4   Месячная годовщина войны, был одним из самых т...
# 5   Сплошное расстройство. Получил отпуск до 9, хо...
# 6   Первый месяц войны прошел.    \nВ 10.20 веч[ер...
# 7   Сегодня в 6 утра сменился с дежурства. В 3.30 ...
# 8   Тридцать первый день войны. Вторник. Утром по ...
# 9   Прошел месяц войны. На заводе револьверных ста...
# 10  ...в центре города вспыхнул пожар, густой дым ...
# 11  Лес восточнее Гуровки .Привезли раненых из 43 ...
# 12  Киев.    \nНас посадили в специальный поезд дл...
# 13  Эти дни мы пололи «культуры» (саженые сосенки)...
# 14  Ночью нас заели. Утром купила карася. Делала в...
# 15  Письма мне пишите на арбатский адрес, так как ...
# 16  Сегодня месяц войны. Немцы заняли большой кусо...
# 17  Скука! Я половину стихов Маяковского наизусть ...
# 18  Сегодня месяц войны. Ночью наблюдали первый бо...
# 19  Месяц войны.    \nВ 10 вечера, когда еще было ...
# 20  Утром радио сообщило, что ночью был налет на М...
# 21  Ночь — спокойно, но около 9 ч. на 40 минут тре...
# 22  Марш был недолгим, только до деревни Осницы. Т...
# 23                           \n### Сезон 1941/42 года
# 24  Ночью 31 октября уже поездом перебросили в гор...

# %% [markdown]
# # простая гистограмма до соноризации

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
tone_text = pd.read_csv('C:/Users/yayar/OneDrive/Рабочий стол/b2/sonicDataAnalizeYaro/csv/22DataTone.csv',delimiter=',')

# %%
mpl.style.use('dark_background')

# %%
tone_text
# Out:
#     positive  negative   neutral
# 0   0.000000  0.000010  1.000010
# 1   0.000000  0.206904  0.437833
# 2   0.000000  0.268951  0.607673
# 3   0.000000  0.206904  0.320831
# 4   0.000000  0.275140  0.314061
# 5   0.000000  0.384922  0.000000
# 6   0.201823  0.370235  0.000000
# 7   0.000000  0.327678  0.000000
# 8   0.000000  0.307368  0.275140
# 9   0.000000  0.239359  0.531219
# 10  0.000000  0.515630  0.320831
# 11  0.000000  0.160276  0.771854
# 12  0.000000  0.256842  0.262852
# 13  0.000000  0.281416  0.782673
# 14  0.000000  0.492198  0.268951
# 15  0.000000  0.275140  0.268951
# 16  0.000000  0.000010  0.384922
# 17  0.000000  0.000010  0.320831
# 18  0.000000  0.348655  1.000010
# 19  0.000000  0.239359  1.000010
# 20  0.000000  0.222710  0.245095
# 21  0.000000  0.233716  0.399822
# 22  0.000000  0.262852  0.000000
# 23  0.000000  0.182436  0.384922
# 24  0.000000  0.000010  0.000000
# 25  0.000000  0.000010  0.362979
# 26  0.000000  0.000010  0.314061
# 27  0.000000  0.287778  0.500010

# %%
pozitive = tone_text['positive']
# negative = tone['-']
# neutrale = tone['0']

# %% [markdown]
# график плотности а не частоты

# %%
mean_m =  tone_text['positive'].mean()
neutrale_proc = (tone_text['positive'].count() + tone_text['negative'].count())/tone_text['neutral'].count()

plt.hist(tone_text['positive'],
          ec = 'black',
         color = 'tab:green',
         alpha = 0.4,
         rwidth = 0.9,
          bins = 5,
        label = 'pozitive',
        density = True)
plt.hist(tone_text['negative'],
          ec = 'black',
         color = 'tab:red',
         alpha = 0.4,
         rwidth = 0.9,
          bins = 5,
        label = 'nefative',
         density = True)
plt.hist(tone_text['neutral'],
          ec = 'black',
         color = 'tab:blue',
         alpha = 0.4,
         rwidth = 0.9,
          bins = 5,
        label = 'neutrale',
         density = True)

plt.axvline(x = mean_m, color = 'orange', lw=2, ls = '-.')

#plt.axvline(x = neutrale_proc, color = 'grey', lw=2, ls = '-')
plt.xlabel('результат оценки')
plt.ylabel('?')
plt.title('Тональность текстов')
plt.legend(loc = 'best')
        
plt.show()

# %%
plt.scatter(x = 'positive', y = 'negative',data = tone_text,
          color = 'tab:blue',
            s = 300,
            marker = '.',
           )

plt.title('негативные и позитивные тексты')
plt.ylabel('негативность')
plt.xlabel('позитивность')
plt.show()

# %%
neu_pro = tone_text['neutral']value_counts()
plt.barh(x = 0.index(),
         heignt = 0
plt.show()
# Out:
#   File "C:\Users\yayar\AppData\Local\Temp/ipykernel_3408/238487152.py", line 1
#     neu_pro = tone_text['neutral']value_counts()
#                                   ^
# SyntaxError: invalid syntax

# %%
tone_color = {'+':'tab:green','-':'tab:red','0':'tab:blue'}

# %%
import os

# %%
os.chdir('..')

# %%
paper =  pd.read_csv('22Data.csv',delimiter=',')

# %%
papper = all[['text']]

# %%
papper.head()

# %%
import re


# Remove punctuation
papper['text_processed'] = \
papper['text'].map(lambda x: re.sub('[,\.!?]', '', x))
# Convert the titles to lowercase
papper['text_processed'] = \
papper['text_processed'].map(lambda x: x.lower())
# Print out the first rows of papers
papper['text_processed'].head()

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = ','.join(list(papper['text_processed'].values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="black", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk
out = open('C:/Users/yayar/OneDrive/Documents/текст дисертации Ярочкин/публикации/sonicDataAnalizeYaro/dostoevsky/dosroevsky_data/row.txt','w', encoding='utf8')
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('russian')
stop_words.extend(['в', 'на', 'и', 'не', 'за','b','евгения','михаиловна'])
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]
data = papper.text_processed.values.tolist()
data_words = list(sent_to_words(data))
# remove stop words
data_words = remove_stopwords(data_words)
print(data_words[:1][0][:30])

# %%
import gensim.corpora as corpora
# Create Dictionary
id2word = corpora.Dictionary(data_words)
# Create Corpus
texts = data_words
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus[:1][0][:30])

# %%
from pprint import pprint
out = open('../dostoevsky/topic_data1.txt','w', encoding='utf8')
# number of topics
num_topics = 200
# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)
s = lda_model.print_topics()# Print the Keyword in the 10 topics
pprint(s)

print(lda_model.print_topics(), file = out)
doc_lda = lda_model[corpus]

# %%
import pyLDAvis.gensim
import pickle 
import pyLDAvis
# Visualize the topics
pyLDAvis.enable_notebook()
LDAvis_data_filepath = os.path.join('./results/ldavis_prepared_'+str(num_topics))
# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
if 1 == 1:
    LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(LDAvis_prepared, f)
# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)
pyLDAvis.save_html(LDAvis_prepared, './results/ldavis_prepared_'+ str(num_topics) +'.html')
LDAvis_prepared
